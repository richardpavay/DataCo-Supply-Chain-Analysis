# %% [markdown]
# #### Importing libraries and data

# %%
# importing libraries
import pandas as pd
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
# importing website traffic data
path = r'C:\Users\Richárd\Desktop\CareerFoundry\Data Immersion\Achievement 6\project\Data'
data = pd.read_csv(os.path.join(path, 'tokenized_access_logs.csv'))

# %% [markdown]
# #### Data Cleaning / Preprocessing

# %%
data.shape
# Out:
# (469977, 8)

# %%
data.head()
# Out:
#                                       Product             Category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             Date Month  Hour Department              ip  \
# 0  9/1/2017 6:00   Sep     6   fitness     37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop     206.56.112.1
# 2  9/1/2017 6:00   Sep     6   apparel    215.143.180.0
# 3  9/1/2017 6:00   Sep     6  footwear     206.56.112.1
# 4  9/1/2017 6:01   Sep     6  fan shop   136.108.56.242
#
#                                                  url
# 0  /department/fitness/category/baseball%20&%20so...
# 1  /department/fan%20shop/category/hunting%20&%20...
# 2  /department/apparel/category/featured%20shops/...
# 3  /department/footwear/category/electronics/prod...
# 4  /department/fan%20shop/category/water%20sports...

# %%
data.dtypes
# Out:
# Product       object
# Category      object
# Date          object
# Month         object
# Hour           int64
# Department    object
# ip            object
# url           object
# dtype: object

# %%
# chcking for null values
data.isnull().sum()
# Out:
# Product       0
# Category      0
# Date          0
# Month         0
# Hour          0
# Department    0
# ip            0
# url           0
# dtype: int64

# %%
# checking for duplicates
dups = data[data.duplicated()]

# %%
dups.shape
# Out:
# (3249, 8)

# %%
3249 / 469977
# Out:
# 0.0069131042582934905

# %% [markdown]
# - Even though there are duplicates, upon a closer look it is wisible that they might be still valid clicks, I see no reason to remove them

# %%
# smoothing dates to daily basis
import datetime
data['Day'] = data['Date'].apply(lambda x: pd.to_datetime(x))

# %%
data['Day'] = data['Day'].apply(lambda x: x.date())

# %%
data.head()
# Out:
#                                       Product             Category  \
# 0     adidas Brazuca 2017 Official Match Ball  baseball & softball
# 1       The North Face Women's Recon Backpack   hunting & shooting
# 2      adidas Kids' RG III Mid Football Cleat       featured shops
# 3  Under Armour Men's Compression EV SL Slide          electronics
# 4                 Pelican Sunstream 100 Kayak         water sports
#
#             Date Month  Hour Department              ip  \
# 0  9/1/2017 6:00   Sep     6   fitness     37.97.182.65
# 1  9/1/2017 6:00   Sep     6  fan shop     206.56.112.1
# 2  9/1/2017 6:00   Sep     6   apparel    215.143.180.0
# 3  9/1/2017 6:00   Sep     6  footwear     206.56.112.1
# 4  9/1/2017 6:01   Sep     6  fan shop   136.108.56.242
#
#                                                  url         Day
# 0  /department/fitness/category/baseball%20&%20so...  2017-09-01
# 1  /department/fan%20shop/category/hunting%20&%20...  2017-09-01
# 2  /department/apparel/category/featured%20shops/...  2017-09-01
# 3  /department/footwear/category/electronics/prod...  2017-09-01
# 4  /department/fan%20shop/category/water%20sports...  2017-09-01

# %%
# Creating a subset to work with
time_series = data[['Day', 'Category', 'ip']]

# %%
# setting up for plotting data
to_plot = time_series.groupby(['Day', 'Category']).agg('count')

# %%
to_plot.head()
# Out:
#                                 ip
# Day        Category
# 2017-09-01 accessories          50
#            as seen on  tv!      77
#            baseball & softball  78
#            basketball           80
#            boxing & mma         62

# %%
# plotting the data
fig = px.line(to_plot.reset_index(), x = 'Day', y = 'ip', color = 'Category')
fig.show()

# %% [markdown]
#  - Looks like something strange was going on on 14 Sep 2017 - could be an attack on the site?

# %%
# checking if many clicks on 14SEP2017 came from the same ip
from datetime import datetime
data[data['Day'] == datetime.strptime('09-14-2017', '%m-%d-%Y').date()].value_counts('ip').max()
# does not seem so
# Out:
# 38
